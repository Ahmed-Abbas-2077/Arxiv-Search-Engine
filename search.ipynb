# %% [markdown]
# # Converting from JSON to CSV

# %%
# !pip install ujson

# %%
import ujson as json
import pandas as pd

with open("arxiv-metadata-oai-snapshot.json", "r") as f:
    data = [json.loads(line) for line in f]
df = pd.DataFrame(data)

# %%
df
# Out:
#                        id           submitter  \
# 0               0704.0001      Pavel Nadolsky
# 1               0704.0002        Louis Theran
# 2               0704.0003         Hongjun Pan
# 3               0704.0004        David Callan
# 4               0704.0005  Alberto Torchinsky
# ...                   ...                 ...
# 2683171  supr-con/9608008     Ruslan Prozorov
# 2683172  supr-con/9609001  Durga P. Choudhury
# 2683173  supr-con/9609002  Durga P. Choudhury
# 2683174  supr-con/9609003   Hasegawa Yasumasa
# 2683175  supr-con/9609004    Masanori Ichioka
#
#                                                    authors  \
# 0        C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                          Ileana Streinu and Louis Theran
# 2                                              Hongjun Pan
# 3                                             David Callan
# 4                 Wael Abu-Shammala and Alberto Torchinsky
# ...

# %%
# df.to_csv('arxiv-metadata-oai-snapshot.csv', index=False)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# - Tokenization: Split documents into individual words or tokens.
# - Lowercasing: Convert all text to lowercase for case insensitivity.
# - Stopword Removal: Eliminate common words (e.g., "and", "the", "is") that do not contribute much to the meaning of the document.
# - Stemming or Lemmatization: Reduce words to their base or root form (e.g. "running" to "run").

# %%
import pandas as pd
dfCsv = pd.read_csv('arxiv-metadata-oai-snapshot.csv', nrows=10000)
dfCsv
# Out:
#             id             submitter  \
# 0     704.0001        Pavel Nadolsky
# 1     704.0002          Louis Theran
# 2     704.0003           Hongjun Pan
# 3     704.0004          David Callan
# 4     704.0005    Alberto Torchinsky
# ...        ...                   ...
# 9995  706.1309  E. V. Sampathkumaran
# 9996  706.1310       Susanne Reffert
# 9997  706.1311          Max Lieblich
# 9998  706.1312          Labib Haddad
# 9999  706.1313      Thierry Coulbois
#
#                                                 authors  \
# 0     C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                       Ileana Streinu and Louis Theran
# 2                                           Hongjun Pan
# 3                                          David Callan
# 4              Wael Abu-Shammala and Alberto Torchinsky
# ...                                                 ...
# 9995              Kartik K Iyer and E.V. Sampathkumaran
# 9996                                         S. Reffert
# ...

# %% [markdown]
# ## Tokenization

# %%
import nltk
nltk.download("punkt_tab")
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
dfCsv['abstract_token'] = dfCsv['abstract'].apply(word_tokenize)
dfCsv['abstract_token']
# Out:
# 0       [A, fully, differential, calculation, in, pert...
# 1       [We, describe, a, new, algorithm, ,, the, $, (...
# 2       [The, evolution, of, Earth-Moon, system, is, d...
# 3       [We, show, that, a, determinant, of, Stirling,...
# 4       [In, this, paper, we, show, how, to, compute, ...
#                               ...
# 9995    [The, compound, Y2PdGe3, was, earlier, reporte...
# 9996    [These, lecture, notes, are, meant, to, serve,...
# 9997    [We, present, a, method, for, compactifying, s...
# 9998    [Full, details, are, given, for, the, definiti...
# 9999    [We, continue, in, this, article, the, study, ...
# Name: abstract_token, Length: 10000, dtype: object

# %% [markdown]
# ## Lowercasing

# %%
dfCsv['abstract_token'] = dfCsv['abstract_token'].apply(lambda x: [word.lower() for word in x])
dfCsv['abstract_token']
# Out:
# 0       [a, fully, differential, calculation, in, pert...
# 1       [we, describe, a, new, algorithm, ,, the, $, (...
# 2       [the, evolution, of, earth-moon, system, is, d...
# 3       [we, show, that, a, determinant, of, stirling,...
# 4       [in, this, paper, we, show, how, to, compute, ...
#                               ...
# 9995    [the, compound, y2pdge3, was, earlier, reporte...
# 9996    [these, lecture, notes, are, meant, to, serve,...
# 9997    [we, present, a, method, for, compactifying, s...
# 9998    [full, details, are, given, for, the, definiti...
# 9999    [we, continue, in, this, article, the, study, ...
# Name: abstract_token, Length: 10000, dtype: object

# %% [markdown]
# ## Stopword Removal

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dfCsv['abstract_token'] = dfCsv['abstract_token'].apply(lambda x: [word for word in x if word not in stop_words])
dfCsv['abstract_token']
# Out:
# 0       [fully, differential, calculation, perturbativ...
# 1       [describe, new, algorithm, ,, $, (, k, ,, \ell...
# 2       [evolution, earth-moon, system, described, dar...
# 3       [show, determinant, stirling, cycle, numbers, ...
# 4       [paper, show, compute, $, \lambda_, {, \alpha,...
#                               ...
# 9995    [compound, y2pdge3, earlier, reported, us, one...
# 9996    [lecture, notes, meant, serve, introduction, g...
# 9997    [present, method, compactifying, stacks, $, \p...
# 9998    [full, details, given, definition, constructio...
# 9999    [continue, article, study, laminations, dual, ...
# Name: abstract_token, Length: 10000, dtype: object

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
wordnet = nltk.corpus.wordnet

# %%
def get_pos(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
wnl = WordNetLemmatizer()

# %%
def lem(tokens):
    # Tag tokens with POS
    tagged = nltk.pos_tag(tokens)
    
    lemmatized = [
        wnl.lemmatize(word, get_pos(tag))
        for word, tag in tagged
    ]
    
    return lemmatized

# %%
words = ['running', 'ran', 'runs', 'run']
lem(words)
# Out:
# ['run', 'run', 'run', 'run']

# %%
dfCsv['abstract_token'] = dfCsv['abstract_token'].apply(lem)
dfCsv['abstract_token']
# Out:
# 0       [fully, differential, calculation, perturbativ...
# 1       [describe, new, algorithm, ,, $, (, k, ,, \ell...
# 2       [evolution, earth-moon, system, describe, dark...
# 3       [show, determinant, stirling, cycle, number, c...
# 4       [paper, show, compute, $, \lambda_, {, \alpha,...
#                               ...
# 9995    [compound, y2pdge3, earlier, report, u, one, t...
# 9996    [lecture, note, mean, serve, introduction, geo...
# 9997    [present, method, compactifying, stack, $, \pg...
# 9998    [full, detail, give, definition, construction,...
# 9999    [continue, article, study, lamination, dual, s...
# Name: abstract_token, Length: 10000, dtype: object

# %%
wnl.lemmatize(word, pos='v')
# Out:
# 'contributions'

# %% [markdown]
# # Indexing and Retrieval

# %%
# turn the list of tokens back into a string
dfCsv['processed_abstract'] = dfCsv['abstract_token'].apply(lambda x: ' '.join(x))
dfCsv['processed_abstract']
# Out:
# 0       fully differential calculation perturbative qu...
# 1       describe new algorithm , $ ( k , \ell ) $ -peb...
# 2       evolution earth-moon system describe dark matt...
# 3       show determinant stirling cycle number count u...
# 4       paper show compute $ \lambda_ { \alpha } $ nor...
#                               ...
# 9995    compound y2pdge3 earlier report u one ternary ...
# 9996    lecture note mean serve introduction geometric...
# 9997    present method compactifying stack $ \pgl_n $ ...
# 9998    full detail give definition construction wreat...
# 9999    continue article study lamination dual small a...
# Name: processed_abstract, Length: 10000, dtype: object

# %%
# creating a new column that is the string version of id
dfCsv['docno'] = dfCsv['id'].astype(str)
dfCsv['docno']
# Out:
# 0       704.0001
# 1       704.0002
# 2       704.0003
# 3       704.0004
# 4       704.0005
#           ...
# 9995    706.1309
# 9996     706.131
# 9997    706.1311
# 9998    706.1312
# 9999    706.1313
# Name: docno, Length: 10000, dtype: object

# %%
# !pip install python-terrier

# %%
import pyterrier as pt

if not pt.java.started():
    pt.java.init()

# %%
docs = []
for i, row in dfCsv.iterrows():
    docs.append({
        "docno": row['docno'],
        "text": row['processed_abstract']
    })

# %%
docs
# Out:
# [{'docno': '704.0001',
#   'text': 'fully differential calculation perturbative quantum chromodynamics present production massive photon pair hadron collider . next-to-leading order perturbative contribution quark-antiquark , gluon- ( anti ) quark , gluon-gluon subprocesses include , well all-orders resummation initial-state gluon radiation valid next-to-next-to-leading logarithmic accuracy . region phase space specify calculation reliable . good agreement demonstrate data fermilab tevatron , prediction make detailed test cdf data . prediction show distribution diphoton pair produce energy large hadron collider ( lhc ) . distribution diphoton pair decay higgs boson contrast produced qcd process lhc , show enhanced sensitivity signal obtain judicious selection event .'},
#  {'docno': '704.0002',
# ...

# %%
indexer = pt.terrier.IterDictIndexer(index_path="E:\Zewail\Sophomore Year\DSAI 201\Project\\arxIndexer", overwrite=True)
index_ref = indexer.index(docs)

# %%
print(index_ref.toString())
# Out:
# E:\Zewail\Sophomore Year\DSAI 201\Project\arxIndexer/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 10000
# Number of terms: 21866
# Number of postings: 504967
# Number of fields: 0
# Number of tokens: 712321
# Field names: []
# Positions:   false

# %%
lexicon = index.getLexicon()

for entry in lexicon:
    print(entry.getKey())
# Out:
# 0
# 00
# 000
# 0001
# 0002
# 0004
# 0005
# 0006
# 0007
# 0009
# 000km
# 000yr
# 001
# 0011
# 0012
# 0013
# 0014
# 0015
# 001msun
# 002
# 0021
# 0024
# 0027
# 003
# 0030
# 0033
# 0037
# 0039
# 004
# 0040
# 0044
# 0048
# 005
# 0053
# 0054
# 0058
# 006
# 007
# 0073
# 008
# 0083
# 009
# 01
# 010
# 0102
# 011
# 0112
# 0115
# 012
# 0129
# 013
# 014
# 0140
# 0142
# 0144
# 0146
# 015
# 016
# 017
# 018
# 0187
# 019
# 0190
# 01mag
# 02
# 020
# 0208
# 021
# 022
# 0220
# 0223f
# 023
# 0232
# 0234f
# 0239
# 024
# 025
# 026
# 027
# 028
# 029
# 02mu
# 03
# 030
# 0301
# 0303
# 0305
# 031
# 032
# 0321
# 0325
# 033
# 0330
# 0335
# 034
# 0344
# 035
# 0351
# 036
# 037
# 038
# 038dex
# 03h
# 03msolar
# 04
# 040
# 0408
# 041
# 0417
# 042
# 043
# 044
# 0444
# 045
# 0455
# 0458
# 046
# 0469
# 048
# 049
# 05
# 050
# 0507
# 051
# 052
# 0521
# 0528
# 052w
# 053
# 0534
# 054
# 0540
# 055
# 0550
# 056
# 057
# 0574
# 058
# 059
# 0597
# 05a
# 05cuo4
# 05te
# 06
# 060
# 0603
# 061
# 0614
# 062
# 0657
# 066
# 0667
# ...

# %%
for x in index.getLexicon():
  print("%s : %s " % (x.getKey(), x.getValue().toString()))
# Out:
# 0 : term196 Nt=1583 TF=4094 maxTF=28 @{0 0 0}
# 00 : term3384 Nt=8 TF=17 maxTF=10 @{0 1417 1}
# 000 : term6071 Nt=30 TF=35 maxTF=4 @{0 1438 4}
# 0001 : term13215 Nt=3 TF=3 maxTF=1 @{0 1497 1}
# 0002 : term10416 Nt=1 TF=1 maxTF=1 @{0 1506 1}
# 0004 : term12322 Nt=2 TF=2 maxTF=1 @{0 1509 1}
# 0005 : term18990 Nt=1 TF=1 maxTF=1 @{0 1515 3}
# 0006 : term19490 Nt=1 TF=1 maxTF=1 @{0 1518 5}
# 0007 : term5132 Nt=3 TF=4 maxTF=2 @{0 1521 7}
# 0009 : term10212 Nt=1 TF=1 maxTF=1 @{0 1530 2}
# 000km : term12731 Nt=1 TF=1 maxTF=1 @{0 1533 2}
# 000yr : term9796 Nt=1 TF=1 maxTF=1 @{0 1536 2}
# 001 : term349 Nt=28 TF=33 maxTF=4 @{0 1539 2}
# 0011 : term6865 Nt=3 TF=3 maxTF=1 @{0 1598 5}
# 0012 : term3684 Nt=1 TF=1 maxTF=1 @{0 1606 7}
# 0013 : term7690 Nt=1 TF=1 maxTF=1 @{0 1609 1}
# 0014 : term1430 Nt=1 TF=1 maxTF=1 @{0 1611 7}
# 0015 : term15725 Nt=1 TF=1 maxTF=1 @{0 1613 3}
# 001msun : term19131 Nt=1 TF=1 maxTF=1 @{0 1616 5}
# 002 : term7691 Nt=9 TF=10 maxTF=2 @{0 1619 7}
# ...

# %%
index.getLexicon()["learn"].toString()
# Out:
# 'term1226 Nt=46 TF=96 maxTF=10 @{0 361284 6}'

# %%
index.getLexicon()["python"].toString()
# Out:
# 'term12202 Nt=4 TF=6 maxTF=2 @{0 507004 2}'

# %%
index.getLexicon()["now"].toString()
# Out:
# 'term16808 Nt=1 TF=1 maxTF=1 @{0 433988 1}'

# %%
def preprocess(query):
    query = word_tokenize(query) # tokenize
    query = [word.lower() for word in query] # lowercase
    query = [word for word in query if word not in stop_words] # remove stopwords
    query = lem(query) # lemmatize
    query = ' '.join(query) # back to string
    return query

# %%
def search_term(term):
    term = preprocess(term)
    print(f"\n Searching for: {term}")

    try:
        pointer = index.getLexicon()[term]
        for posting in index.getInvertedIndex().getPostings(pointer):
            print(f"Document ID: {posting.getId()}, Length: {posting.getDocumentLength()}")
    except KeyError:
        print(f" Term '{term}' not found in the index.")

# %%
search_term("python")
# Out:
#  Searching for: python
# Document ID: 3181, Length: 33
# Document ID: 3258, Length: 36
# Document ID: 8431, Length: 148
# Document ID: 8875, Length: 113
