# %% [markdown]
# # Converting from JSON to CSV

# %%
# !pip install ujson
# Out:
# Requirement already satisfied: ujson in d:\anaconda3\envs\koraenv\lib\site-packages (5.10.0)

# %%
import ujson as json
import pandas as pd

with open("arxiv-metadata-oai-snapshot.json", "r") as f:
    data = [json.loads(line) for line in f]
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import ujson as json
# ----> 2 import pandas as pd
#       4 with open("arxiv-metadata-oai-snapshot.json", "r") as f:
#       5     data = [json.loads(line) for line in f]
#
# File d:\Anaconda3\envs\koraEnv\lib\site-packages\pandas\__init__.py:77
#      74 # let init-time option registration happen
#      75 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 77 from pandas.core.api import (
#      78     # dtype
#      79     ArrowDtype,
#      80     Int8Dtype,
#      81     Int16Dtype,
#      82     Int32Dtype,
#      83     Int64Dtype,
#      84     UInt8Dtype,
#      85     UInt16Dtype,
#      86     UInt32Dtype,
#      87     UInt64Dtype,
#      88     Float32Dtype,
#      89     Float64Dtype,
#      90     CategoricalDtype,
#      91     PeriodDtype,
#      92     IntervalDtype,
#      93     DatetimeTZDtype,
#      94     StringDtype,
#      95     BooleanDtype,
#      96     # missing
#      97     NA,
#      98     isna,
#      99     isnull,
#     100     notna,
#     101     notnull,
#     102     # indexes
#     103     Index,
#     104     CategoricalIndex,
#     105     RangeIndex,
#     106     MultiIndex,
#     107     IntervalIndex,
#     108     TimedeltaIndex,
#     109     DatetimeIndex,
#     110     PeriodIndex,
#     111     IndexSlice,
#     112     # tseries
#     113     NaT,
#     114     Period,
#     115     period_range,
#     116     Timedelta,
#     117     timedelta_range,
#     118     Timestamp,
#     119     date_range,
#     120     bdate_range,
#     121     Interval,
#     122     interval_range,
#     123     DateOffset,
#     124     # conversion
#     125     to_numeric,
#     126     to_datetime,
#     127     to_timedelta,
#     128     # misc
#     129     Flags,
#     130     Grouper,
#     131     factorize,
#     132     unique,
#     133     value_counts,
#     134     NamedAgg,
#     135     array,
#     136     Categorical,
#     137     set_eng_float_format,
#     138     Series,
#     139     DataFrame,
#     140 )
#     142 from pandas.core.dtypes.dtypes import SparseDtype
#     144 from pandas.tseries.api import infer_freq
#
# File d:\Anaconda3\envs\koraEnv\lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File d:\Anaconda3\envs\koraEnv\lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# File interval.pyx:1, in init pandas._libs.interval()
#
# File hashtable.pyx:1, in init pandas._libs.hashtable()
#
# File missing.pyx:1, in init pandas._libs.missing()
#
# File d:\Anaconda3\envs\koraEnv\lib\site-packages\pandas\_libs\tslibs\__init__.py:40
#       1 __all__ = [
#       2     "dtypes",
#       3     "localize_pydatetime",
#    (...)
#      36     "is_supported_dtype",
#      37 ]
#      39 from pandas._libs.tslibs import dtypes  # pylint: disable=import-self
# ---> 40 from pandas._libs.tslibs.conversion import localize_pydatetime
#      41 from pandas._libs.tslibs.dtypes import (
#      42     Resolution,
#      43     periods_per_day,
#      44     periods_per_second,
#      45 )
#      46 from pandas._libs.tslibs.nattype import (
#      47     NaT,
#      48     NaTType,
#      49     iNaT,
#      50     nat_strings,
#      51 )
#
# File conversion.pyx:1, in init pandas._libs.tslibs.conversion()
#
# File offsets.pyx:1, in init pandas._libs.tslibs.offsets()
#
# File <frozen importlib._bootstrap>:398, in parent(self)
#
# KeyboardInterrupt:

# %%
df
# Out:
#                        id           submitter  \
# 0               0704.0001      Pavel Nadolsky
# 1               0704.0002        Louis Theran
# 2               0704.0003         Hongjun Pan
# 3               0704.0004        David Callan
# 4               0704.0005  Alberto Torchinsky
# ...                   ...                 ...
# 2683171  supr-con/9608008     Ruslan Prozorov
# 2683172  supr-con/9609001  Durga P. Choudhury
# 2683173  supr-con/9609002  Durga P. Choudhury
# 2683174  supr-con/9609003   Hasegawa Yasumasa
# 2683175  supr-con/9609004    Masanori Ichioka
#
#                                                    authors  \
# 0        C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                          Ileana Streinu and Louis Theran
# 2                                              Hongjun Pan
# 3                                             David Callan
# 4                 Wael Abu-Shammala and Alberto Torchinsky
# ...                                                    ...
# 2683171  R. Prozorov, M. Konczykowski, B. Schmidt, Y. Y...
# 2683172  Durga P. Choudhury, Balam A. Willemsen, John S...
# 2683173  Balam A. Willemsen, J. S. Derov and S.Sridhar ...
# 2683174  Yasumasa Hasegawa (Himeji Institute of Technol...
# 2683175  Naoki Enomoto, Masanori Ichioka and Kazushige ...
#
#                                                      title  \
# 0        Calculation of prompt diphoton production cros...
# 1                 Sparsity-certifying Graph Decompositions
# 2        The evolution of the Earth-Moon system based o...
# 3        A determinant of Stirling cycle numbers counts...
# 4        From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                    ...
# 2683171  On the origin of the irreversibility line in t...
# 2683172  Nonlinear Response of HTSC Thin Film Microwave...
# 2683173  Critical State Flux Penetration and Linear Mic...
# 2683174  Density of States and NMR Relaxation Rate in A...
# 2683175  Ginzburg Landau theory for d-wave pairing and ...
#
#                                                   comments  \
# 0                  37 pages, 15 figures; published version
# 1                    To appear in Graphs and Combinatorics
# 2                                      23 pages, 3 figures
# 3                                                 11 pages
# 4                                                     None
# ...                                                    ...
# 2683171  19 pages, LaTex, 6 PostScript figures; Author'...
# 2683172  4 pages, LaTeX type, Uses IEEE style files, 60...
# 2683173  20 pages, LaTeX type, Uses REVTeX style files,...
# 2683174  7 pages, 4 PostScript Figures, LaTeX, to appea...
# 2683175  12 pages including 8 eps figs, LaTeX with jpsj...
#
#                                        journal-ref  \
# 0                         Phys.Rev.D76:013009,2007
# 1                                             None
# 2                                             None
# 3                                             None
# 4        Illinois J. Math. 52 (2008) no.2, 681-689
# ...                                            ...
# 2683171                                       None
# 2683172                                       None
# 2683173                                       None
# 2683174                                       None
# 2683175         J. Phys. Soc. Jpn. 66, 204 (1997).
#
#                                 doi         report-no  \
# 0        10.1103/PhysRevD.76.013009  ANL-HEP-PR-07-12
# 1                              None              None
# 2                              None              None
# 3                              None              None
# 4                              None              None
# ...                             ...               ...
# 2683171   10.1103/PhysRevB.54.15530              None
# 2683172           10.1109/77.620744              None
# 2683173   10.1103/PhysRevB.56.11989              None
# 2683174        10.1143/JPSJ.65.3131              None
# 2683175         10.1143/JPSJ.66.204              None
#
#                          categories  \
# 0                            hep-ph
# 1                     math.CO cs.CG
# 2                    physics.gen-ph
# 3                           math.CO
# 4                   math.CA math.FA
# ...                             ...
# 2683171  supr-con cond-mat.supr-con
# 2683172  supr-con cond-mat.supr-con
# 2683173  supr-con cond-mat.supr-con
# 2683174  supr-con cond-mat.supr-con
# 2683175  supr-con cond-mat.supr-con
#
#                                                    license  \
# 0                                                     None
# 1        http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                     None
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 2683171                                               None
# 2683172                                               None
# 2683173                                               None
# 2683174                                               None
# 2683175                                               None
#
#                                                   abstract  \
# 0          A fully differential calculation in perturba...
# 1          We describe a new algorithm, the $(k,\ell)$-...
# 2          The evolution of Earth-Moon system is descri...
# 3          We show that a determinant of Stirling cycle...
# 4          In this paper we show how to compute the $\L...
# ...                                                    ...
# 2683171    We report on measurements of the angular dep...
# 2683172    The non-linear microwave surface impedance o...
# 2683173    The vortex contribution to the dc field (H) ...
# 2683174    We show that the density of states in an ani...
# 2683175    The Ginzburg Landau theory for d_{x^2-y^2}-w...
#
#                                                   versions update_date  \
# 0        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2        [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3        [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4        [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                    ...         ...
# 2683171  [{'version': 'v1', 'created': 'Mon, 26 Aug 199...  2009-10-30
# 2683172  [{'version': 'v1', 'created': 'Sat, 31 Aug 199...  2016-11-18
# 2683173  [{'version': 'v1', 'created': 'Tue, 3 Sep 1996...  2009-10-30
# 2683174  [{'version': 'v1', 'created': 'Wed, 18 Sep 199...  2009-10-30
# 2683175  [{'version': 'v1', 'created': 'Wed, 25 Sep 199...  2009-10-30
#
#                                             authors_parsed
# 0        [[Balázs, C., ], [Berger, E. L., ], [Nadolsky,...
# 1                 [[Streinu, Ileana, ], [Theran, Louis, ]]
# 2                                       [[Pan, Hongjun, ]]
# 3                                      [[Callan, David, ]]
# 4        [[Abu-Shammala, Wael, ], [Torchinsky, Alberto, ]]
# ...                                                    ...
# 2683171  [[Prozorov, R., ], [Konczykowski, M., ], [Schm...
# 2683172  [[Choudhury, Durga P., , Physics Department, N...
# 2683173  [[Willemsen, Balam A., , Physics Department,\n...
# 2683174  [[Hasegawa, Yasumasa, , Himeji Institute of Te...
# 2683175  [[Enomoto, Naoki, , Okayama Univ.], [Ichioka, ...
#
# [2683176 rows x 14 columns]

# %%
# df.to_csv('arxiv-metadata-oai-snapshot.csv', index=False)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# - Tokenization: Split documents into individual words or tokens.
# - Lowercasing: Convert all text to lowercase for case insensitivity.
# - Stopword Removal: Eliminate common words (e.g., "and", "the", "is") that do not contribute much to the meaning of the document.
# - Stemming or Lemmatization: Reduce words to their base or root form (e.g. "running" to "run").

# %%
import pandas as pd
dfCsv = pd.read_csv('arxiv-metadata-oai-snapshot.csv', nrows=10000)
dfCsv
# Out:
#             id             submitter  \
# 0     704.0001        Pavel Nadolsky
# 1     704.0002          Louis Theran
# 2     704.0003           Hongjun Pan
# 3     704.0004          David Callan
# 4     704.0005    Alberto Torchinsky
# ...        ...                   ...
# 9995  706.1309  E. V. Sampathkumaran
# 9996  706.1310       Susanne Reffert
# 9997  706.1311          Max Lieblich
# 9998  706.1312          Labib Haddad
# 9999  706.1313      Thierry Coulbois
#
#                                                 authors  \
# 0     C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                       Ileana Streinu and Louis Theran
# 2                                           Hongjun Pan
# 3                                          David Callan
# 4              Wael Abu-Shammala and Alberto Torchinsky
# ...                                                 ...
# 9995              Kartik K Iyer and E.V. Sampathkumaran
# 9996                                         S. Reffert
# 9997                                       Max Lieblich
# 9998         Barben-Jean Coffi-Nketsia and Labib Haddad
# 9999  Thierry Coulbois (LATP), Arnaud Hilion (LATP),...
#
#                                                   title  \
# 0     Calculation of prompt diphoton production cros...
# 1              Sparsity-certifying Graph Decompositions
# 2     The evolution of the Earth-Moon system based o...
# 3     A determinant of Stirling cycle numbers counts...
# 4     From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
# ...                                                 ...
# 9995  Superconducting behavior of the solid solution...
# 9996  The Geometer's Toolkit to String Compactificat...
# 9997          Compactified moduli of projective bundles
# 9998  Entrelacement d'alg\`ebres de Lie [Wreath prod...
# 9999  Non-unique ergodicity, observers' topology and...
#
#                                                comments  \
# 0               37 pages, 15 figures; published version
# 1                 To appear in Graphs and Combinatorics
# 2                                   23 pages, 3 figures
# 3                                              11 pages
# 4                                                   NaN
# ...                                                 ...
# 9995                                Physica C, in press
# 9996  Lecture notes based on lectures given at the W...
# 9997  28 pages. Major reogranization and clarificati...
# 9998  A moderately detailed english summary of the p...
# 9999          to appear in the Illinois Journal of Math
#
#                                             journal-ref  \
# 0                              Phys.Rev.D76:013009,2007
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4             Illinois J. Math. 52 (2008) no.2, 681-689
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997     Algebra Number Theory 3 (2009), no. 6, 653-695
# 9998                                                NaN
# 9999  Illinois Journal of Mathematics 51 (2007) 897-911
#
#                               doi         report-no  \
# 0      10.1103/PhysRevD.76.013009  ANL-HEP-PR-07-12
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
# ...                           ...               ...
# 9995  10.1016/j.physc.2007.05.049               NaN
# 9996                          NaN               NaN
# 9997                          NaN               NaN
# 9998                          NaN               NaN
# 9999                          NaN               NaN
#
#                              categories  \
# 0                                hep-ph
# 1                         math.CO cs.CG
# 2                        physics.gen-ph
# 3                               math.CO
# 4                       math.CA math.FA
# ...                                 ...
# 9995  cond-mat.supr-con cond-mat.str-el
# 9996                             hep-th
# 9997                    math.AG math.RT
# 9998                            math.RT
# 9999                            math.GR
#
#                                                 license  \
# 0                                                   NaN
# 1     http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997  http://arxiv.org/licenses/nonexclusive-distrib...
# 9998                                                NaN
# 9999                                                NaN
#
#                                                abstract  \
# 0       A fully differential calculation in perturba...
# 1       We describe a new algorithm, the $(k,\ell)$-...
# 2       The evolution of Earth-Moon system is descri...
# 3       We show that a determinant of Stirling cycle...
# 4       In this paper we show how to compute the $\L...
# ...                                                 ...
# 9995    The compound Y2PdGe3 was earlier reported by...
# 9996    These lecture notes are meant to serve as an...
# 9997    We present a method for compactifying stacks...
# 9998    Full details are given for the definition an...
# 9999    We continue in this article the study of lam...
#
#                                                versions update_date  \
# 0     [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1     [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2     [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3     [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4     [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
# ...                                                 ...         ...
# 9995  [{'version': 'v1', 'created': 'Sat, 9 Jun 2007...  2009-11-13
# 9996  [{'version': 'v1', 'created': 'Sat, 9 Jun 2007...  2009-09-29
# 9997  [{'version': 'v1', 'created': 'Mon, 11 Jun 200...  2018-06-18
# 9998  [{'version': 'v1', 'created': 'Sat, 9 Jun 2007...  2007-06-12
# 9999  [{'version': 'v1', 'created': 'Sat, 9 Jun 2007...  2010-02-05
#
#                                          authors_parsed
# 0     [['Balázs', 'C.', ''], ['Berger', 'E. L.', '']...
# 1     [['Streinu', 'Ileana', ''], ['Theran', 'Louis'...
# 2                              [['Pan', 'Hongjun', '']]
# 3                             [['Callan', 'David', '']]
# 4     [['Abu-Shammala', 'Wael', ''], ['Torchinsky', ...
# ...                                                 ...
# 9995  [['Iyer', 'Kartik K', ''], ['Sampathkumaran', ...
# 9996                            [['Reffert', 'S.', '']]
# 9997                          [['Lieblich', 'Max', '']]
# 9998  [['Coffi-Nketsia', 'Barben-Jean', ''], ['Hadda...
# 9999  [['Coulbois', 'Thierry', '', 'LATP'], ['Hilion...
#
# [10000 rows x 14 columns]

# %% [markdown]
# ## Tokenization

# %%
import nltk
nltk.download("punkt_tab")
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
dfCsv['abstract_token'] = dfCsv['abstract'].apply(word_tokenize)
dfCsv['abstract_token']
# Out:
# 0       [A, fully, differential, calculation, in, pert...
# 1       [We, describe, a, new, algorithm, ,, the, $, (...
# 2       [The, evolution, of, Earth-Moon, system, is, d...
# 3       [We, show, that, a, determinant, of, Stirling,...
# 4       [In, this, paper, we, show, how, to, compute, ...
#                               ...
# 9995    [The, compound, Y2PdGe3, was, earlier, reporte...
# 9996    [These, lecture, notes, are, meant, to, serve,...
# 9997    [We, present, a, method, for, compactifying, s...
# 9998    [Full, details, are, given, for, the, definiti...
# 9999    [We, continue, in, this, article, the, study, ...
# Name: abstract_token, Length: 10000, dtype: object

# %% [markdown]
# ## Lowercasing

# %%
dfCsv['abstract_token'] = dfCsv['abstract_token'].apply(lambda x: [word.lower() for word in x])
dfCsv['abstract_token']
# Out:
# 0       [a, fully, differential, calculation, in, pert...
# 1       [we, describe, a, new, algorithm, ,, the, $, (...
# 2       [the, evolution, of, earth-moon, system, is, d...
# 3       [we, show, that, a, determinant, of, stirling,...
# 4       [in, this, paper, we, show, how, to, compute, ...
#                               ...
# 9995    [the, compound, y2pdge3, was, earlier, reporte...
# 9996    [these, lecture, notes, are, meant, to, serve,...
# 9997    [we, present, a, method, for, compactifying, s...
# 9998    [full, details, are, given, for, the, definiti...
# 9999    [we, continue, in, this, article, the, study, ...
# Name: abstract_token, Length: 10000, dtype: object

# %% [markdown]
# ## Stopword Removal

# %%
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dfCsv['abstract_token'] = dfCsv['abstract_token'].apply(lambda x: [word for word in x if word not in stop_words])
dfCsv['abstract_token']
# Out:
# 0       [fully, differential, calculation, perturbativ...
# 1       [describe, new, algorithm, ,, $, (, k, ,, \ell...
# 2       [evolution, earth-moon, system, described, dar...
# 3       [show, determinant, stirling, cycle, numbers, ...
# 4       [paper, show, compute, $, \lambda_, {, \alpha,...
#                               ...
# 9995    [compound, y2pdge3, earlier, reported, us, one...
# 9996    [lecture, notes, meant, serve, introduction, g...
# 9997    [present, method, compactifying, stacks, $, \p...
# 9998    [full, details, given, definition, constructio...
# 9999    [continue, article, study, laminations, dual, ...
# Name: abstract_token, Length: 10000, dtype: object

# %% [markdown]
# ## Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     d:\Anaconda3\envs\koraEnv\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
wordnet = nltk.corpus.wordnet

# %%
def get_pos(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
wnl = WordNetLemmatizer()

# %%
def lem(tokens):
    # Tag tokens with POS
    tagged = nltk.pos_tag(tokens)
    
    lemmatized = [
        wnl.lemmatize(word, get_pos(tag))
        for word, tag in tagged
    ]
    
    return lemmatized

# %%
words = ['running', 'ran', 'runs', 'run']
lem(words)
# Out:
# ['run', 'run', 'run', 'run']

# %%
dfCsv['abstract_token'] = dfCsv['abstract_token'].apply(lem)
dfCsv['abstract_token']
# Out:
# 0       [fully, differential, calculation, perturbativ...
# 1       [describe, new, algorithm, ,, $, (, k, ,, \ell...
# 2       [evolution, earth-moon, system, describe, dark...
# 3       [show, determinant, stirling, cycle, number, c...
# 4       [paper, show, compute, $, \lambda_, {, \alpha,...
#                               ...
# 9995    [compound, y2pdge3, earlier, report, u, one, t...
# 9996    [lecture, note, mean, serve, introduction, geo...
# 9997    [present, method, compactifying, stack, $, \pg...
# 9998    [full, detail, give, definition, construction,...
# 9999    [continue, article, study, lamination, dual, s...
# Name: abstract_token, Length: 10000, dtype: object

# %%
wnl.lemmatize(word, pos='v')
# Out:
# 'contributions'

# %% [markdown]
# # Indexing and Retrieval

# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Using cached python_terrier-0.13.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (1.26.4)
# Requirement already satisfied: pandas in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (2.2.3)
# Collecting more-itertools (from python-terrier)
#   Using cached more_itertools-10.6.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (4.66.4)
# Requirement already satisfied: requests in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (2.32.2)
# Collecting ir-datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.10-py3-none-any.whl.metadata (12 kB)
# Collecting wget (from python-terrier)
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Using cached pyjnius-1.6.1-cp39-cp39-win_amd64.whl.metadata (10 kB)
# Collecting deprecated (from python-terrier)
#   Using cached Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: scipy in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (1.13.1)
# Collecting ir-measures>=0.3.1 (from python-terrier)
#   Using cached ir_measures-0.3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting pytrec-eval-terrier>=0.5.3 (from python-terrier)
#   Using cached pytrec_eval_terrier-0.5.6-cp39-cp39-win_amd64.whl.metadata (796 bytes)
# Requirement already satisfied: jinja2 in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (3.1.4)
# Collecting statsmodels (from python-terrier)
#   Using cached statsmodels-0.14.4-cp39-cp39-win_amd64.whl.metadata (9.5 kB)
# Collecting dill (from python-terrier)
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: joblib in d:\anaconda3\envs\koraenv\lib\site-packages (from python-terrier) (1.4.2)
# Collecting chest (from python-terrier)
#   Using cached chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting lz4 (from python-terrier)
#   Using cached lz4-4.4.3-cp39-cp39-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in d:\anaconda3\envs\koraenv\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.3)
# Collecting inscriptis>=2.2.0 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached inscriptis-2.5.3-py3-none-any.whl.metadata (25 kB)
# Collecting lxml>=4.5.2 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached lxml-5.3.1-cp39-cp39-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\anaconda3\envs\koraenv\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.1)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting warc3-wet>=0.2.3 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting zlib-state>=0.1.3 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached zlib_state-0.1.9-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Collecting ijson>=3.1.3 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached ijson-3.3.0-cp39-cp39-win_amd64.whl.metadata (22 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets>=0.3.2->python-terrier)
#   Using cached unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyarrow>=16.1.0 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading pyarrow-19.0.1-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\envs\koraenv\lib\site-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\koraenv\lib\site-packages (from requests->python-terrier) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\envs\koraenv\lib\site-packages (from requests->python-terrier) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\koraenv\lib\site-packages (from requests->python-terrier) (2024.8.30)
# Requirement already satisfied: colorama in d:\anaconda3\envs\koraenv\lib\site-packages (from tqdm->python-terrier) (0.4.6)
# Collecting heapdict (from chest->python-terrier)
#   Using cached HeapDict-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting wrapt<2,>=1.10 (from deprecated->python-terrier)
#   Using cached wrapt-1.17.2-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\koraenv\lib\site-packages (from jinja2->python-terrier) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\envs\koraenv\lib\site-packages (from pandas->python-terrier) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\koraenv\lib\site-packages (from pandas->python-terrier) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\envs\koraenv\lib\site-packages (from pandas->python-terrier) (2024.1)
# Collecting patsy>=0.5.6 (from statsmodels->python-terrier)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in d:\anaconda3\envs\koraenv\lib\site-packages (from statsmodels->python-terrier) (24.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\envs\koraenv\lib\site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\koraenv\lib\site-packages (from python-dateutil>=2.8.2->pandas->python-terrier) (1.16.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier)
#   Using cached cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using cached python_terrier-0.13.0-py3-none-any.whl (163 kB)
# Downloading ir_datasets-0.5.10-py3-none-any.whl (859 kB)
#    ---------------------------------------- 0.0/859.0 kB ? eta -:--:--
#    ---------------------------------------- 10.2/859.0 kB ? eta -:--:--
#    - ------------------------------------- 30.7/859.0 kB 445.2 kB/s eta 0:00:02
#    ---- ---------------------------------- 92.2/859.0 kB 751.6 kB/s eta 0:00:02
#    -------- ------------------------------- 174.1/859.0 kB 1.2 MB/s eta 0:00:01
#    -------- ------------------------------- 184.3/859.0 kB 1.1 MB/s eta 0:00:01
#    -------- ------------------------------- 184.3/859.0 kB 1.1 MB/s eta 0:00:01
#    -------- ------------------------------- 184.3/859.0 kB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 430.1/859.0 kB 1.4 MB/s eta 0:00:01
#    -------------------- ------------------- 430.1/859.0 kB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 583.7/859.0 kB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 583.7/859.0 kB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 583.7/859.0 kB 1.5 MB/s eta 0:00:01
#    --------------------------- ------------ 583.7/859.0 kB 1.5 MB/s eta 0:00:01
#    -------------------------------- ------- 696.3/859.0 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 859.0/859.0 kB 1.6 MB/s eta 0:00:00
# Using cached ir_measures-0.3.7-py3-none-any.whl (60 kB)
# Using cached lz4-4.4.3-cp39-cp39-win_amd64.whl (99 kB)
# Using cached pyjnius-1.6.1-cp39-cp39-win_amd64.whl (222 kB)
# Using cached pytrec_eval_terrier-0.5.6-cp39-cp39-win_amd64.whl (56 kB)
# Using cached Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached dill-0.3.9-py3-none-any.whl (119 kB)
# Using cached more_itertools-10.6.0-py3-none-any.whl (63 kB)
# Downloading statsmodels-0.14.4-cp39-cp39-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.9 MB 2.0 MB/s eta 0:00:05
#     --------------------------------------- 0.1/9.9 MB 2.1 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.9 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/9.9 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/9.9 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.9 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/9.9 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.9 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/9.9 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/9.9 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/9.9 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18941 sha256=3c08400483fd716b2e4218dcddc38f19d3433dce03a7d04419c4d9711ebd3b01
#   Stored in directory: c:\users\aboab\appdata\local\pip\cache\wheels\7f\22\ed\a11944d7fdf4e94c4206a3f760d385122a4d34d8acc12f71a3
#   Building wheel for cbor (setup.py): started
#   Building wheel for cbor (setup.py): finished with status 'done'
#   Created wheel for cbor: filename=cbor-1.0.0-py3-none-any.whl size=10043 sha256=ba5271095094e0c80848dcededba21166725a78a8b1d01968b00cbce17e16638
#   Stored in directory: c:\users\aboab\appdata\local\pip\cache\wheels\ec\10\03\a281e0682ddd4b310431fb25d1a4f53987105267cf46c417f3
# Successfully built chest wget warc3-wet-clueweb09 cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, pyjnius, ijson, heapdict, cbor, zlib-state, wrapt, unlzw3, trec-car-tools, pytrec-eval-terrier, pyarrow, patsy, more-itertools, lz4, lxml, dill, chest, ir-measures, inscriptis, deprecated, statsmodels, ir-datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 deprecated-1.2.18 dill-0.3.9 heapdict-1.0.1 ijson-3.3.0 inscriptis-2.5.3 ir-datasets-0.5.10 ir-measures-0.3.7 lxml-5.3.1 lz4-4.4.3 more-itertools-10.6.0 patsy-1.0.1 pyarrow-19.0.1 pyjnius-1.6.1 python-terrier-0.13.0 pytrec-eval-terrier-0.5.6 statsmodels-0.14.4 trec-car-tools-2.6 unlzw3-0.2.3 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 wget-3.2 wrapt-1.17.2 zlib-state-0.1.9

# %%
import pyterrier as pt

if not pt.java.started():
    pt.java.init()
# Out:
# terrier-assemblies 5.11 jar-with-dependencies not found, downloading to C:\Users\aboab/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to C:\Users\aboab/.pyterrier...
# Done
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]

# %%
dfCsv['docno'] = dfCsv['id']

# %%
dfCsv['processed_abstract'] = dfCsv['abstract_token'].apply(lambda x: ' '.join(x))
dfCsv['processed_abstract']
# Out:
# 0       fully differential calculation perturbative qu...
# 1       describe new algorithm , $ ( k , \ell ) $ -peb...
# 2       evolution earth-moon system describe dark matt...
# 3       show determinant stirling cycle number count u...
# 4       paper show compute $ \lambda_ { \alpha } $ nor...
#                               ...
# 9995    compound y2pdge3 earlier report u one ternary ...
# 9996    lecture note mean serve introduction geometric...
# 9997    present method compactifying stack $ \pgl_n $ ...
# 9998    full detail give definition construction wreat...
# 9999    continue article study lamination dual small a...
# Name: processed_abstract, Length: 10000, dtype: object

# %%
# Creates an index stored in "myFirstIndex" folder.
indexer = pt.DFIndexer("./ArxivIndex", overwrite=True)

# Indexing our Dataset
index_ref = indexer.index(docs["processed_text"], docs["docno"])

print(index_ref.toString())  #prints where the index is stored/confirms the index was successfully created!
